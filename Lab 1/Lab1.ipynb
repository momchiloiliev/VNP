# %% [markdown]
# # Lab Exercise 1. Scraping Static Websites

# %% [markdown]
# This is the warmup task for the first laboratory exercise. It consists of scraping static Websites with BeautifulSoap.
#
#  It should be completed at home and presented at the laboratory.

# %% [markdown]
# **Total points: 2**

# %% [markdown]
# ### Task Description

# %% [markdown]
# Scrape the information about the products on the following page:
# https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/

# %% [markdown]
# For each product scrape:
#
#
# *   Product title (selector `'.wd-entities-title'`)
# *   Product regular price (selector `'.woocommerce-Price-amount'`)
# *   Product discount price (if available), same selector as regular price
# *   URL to the product page
# *   Add to cart button URL
#
# ***Help: There are multiple product pages, for each page you need to send a separate request***

# %% [markdown]
# Save the results as a DataFrame object

# %% [markdown]
# You can add as many code cells as you need.

# %% [markdown]
# ________________________________________________________________

# %% [markdown]
# ### Requirements

# %% [markdown]
# Import libraries and modules that you are going to use

# %%
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import requests

# %% [markdown]
# ### Send HTTP request to the target Website

# %%
url="https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/"
response=requests.get(url)

# %% [markdown]
# check the response status code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Parse the response content with BeautifulSoap

# %%
soup=BeautifulSoup(response.text,"html.parser")
print(soup.prettify()).
# Out:
#   Cell In[1], line 2
#     print(soup.prettify()).
#                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Extract data from the BeautifulSoap object using any selectors, attribute identifiers, etc.

# %% [markdown]
# * Product title (selector '.wd-entities-title')
# * Product regular price (selector '.woocommerce-Price-amount')
# * Product discount price (if available), same selector as regular price
# * URL to the product page
# * Add to cart button URL

# %%
products=soup.select(".product-wrapper")

# %%
title=products[0].select_one(".wd-entities-title a")
regular_price=products[0].select_one("div.product-wrapper > span > span > bdi").text.split("\xa0")[0]
isOnSale=products[2].select_one(".onsale").text
discount_price=products[2].select(".price span bdi")[1].text.split("\xa0")[0]
url_product_page=products[0].select_one(".hover-img a").get("href")
url_cart_button=products[0].select_one("div.wd-add-btn.wd-add-btn-replace a").get("href")
title.text,regular_price,isOnSale,discount_price,url_product_page,url_product_page+url_cart_button
# Out:
# ('Acer A315-23-A7KD',
#  '17.590',
#  '-16%',
#  '15.999',
#  'https://clevershop.mk/product/acer-a315-23-a7kd/',
#  'https://clevershop.mk/product/acer-a315-23-a7kd/?add-to-cart=21494')

# %%
all_products_on_page=[]
for product in products:
    title=product.select_one(".wd-entities-title a").text
    regular_price=product.select_one(".woocommerce-Price-amount").text.split("\xa0")[0]
    isOnSale=product.select_one(".onsale")
    if isOnSale is not None:
        discount_price=product.select(".price span bdi")[1].text.split("\xa0")[0] 
    else:
        discount_price=None
    url_product_page=product.select_one(".hover-img a").get("href")
    url_cart_button=product.select_one("div.wd-add-btn.wd-add-btn-replace a").get("href")
    product_dict={
        "Title":title,
        "Regular price":regular_price,
        "Discount price":discount_price,
        "Url product page":url_product_page,
        "Url cart page": url_product_page+url_cart_button
    }
    all_products_on_page.append(product_dict)
len(all_products_on_page)
# Out:
# 24

# %% [markdown]
# Repeat the extraction process for each page of products

# %%
def return_product_dict(product):
    title=product.select_one(".wd-entities-title a").text
    regular_price=product.select_one(".woocommerce-Price-amount").text.split("\xa0")[0].replace(".","")
    isOnSale=product.select_one(".onsale")
    if isOnSale is not None:
        discount_price=product.select(".price span bdi")[1].text.split("\xa0")[0].replace(".","")
    else:
        discount_price=None
    url_product_page=product.select_one(".product-image-link").get("href")
    url_cart_button=product.select_one("div.wd-add-btn.wd-add-btn-replace a").get("href")
    product_dict={
        "Title":title,
        "Regular price":regular_price,
        "Discount price":discount_price,
        "Url product page":url_product_page,
        "Url cart page": url_product_page+url_cart_button
    }
    return product_dict

# %%
base_url="https://clevershop.mk/product-category/mobilni-laptopi-i-tableti/page/"
products_on_all_pages=[]
for i in range(1,15):
    url=base_url+str(i)
    response=requests.get(url)
    soup=BeautifulSoup(response.text,"html.parser")
    products=soup.select(".product-wrapper")
    for product in products:
        result=return_product_dict(product)
        products_on_all_pages.append(result)
len(products_on_all_pages)
products_on_all_pages
# Out:
# [{'Title': 'Acer A315-23-A7KD',
#   'Regular price': '17590',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-a315-23-a7kd/',
#   'Url cart page': 'https://clevershop.mk/product/acer-a315-23-a7kd/?add-to-cart=21494'},
#  {'Title': 'Acer A315-23-R5P2',
#   'Regular price': '27490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-a315-23-r5p2/',
#   'Url cart page': 'https://clevershop.mk/product/acer-a315-23-r5p2/?add-to-cart=21510'},
#  {'Title': 'ACER Aspire 1 A115-22',
#   'Regular price': '18999',
#   'Discount price': '15999',
#   'Url product page': 'https://clevershop.mk/product/acer-aspire-1-nx-a7pex-001/',
#   'Url cart page': 'https://clevershop.mk/product/acer-aspire-1-nx-a7pex-001/?add-to-cart=20826'},
#  {'Title': 'Acer Aspire 3 A315-23-R26A',
#   'Regular price': '29990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-aspire-3-a315-23-r26a/',
#   'Url cart page': 'https://clevershop.mk/product/acer-aspire-3-a315-23-r26a/?add-to-cart=21516'},
#  {'Title': 'Acer Aspire 3 A315-58-33WK',
#   'Regular price': '24490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/21498/',
#   'Url cart page': 'https://clevershop.mk/product/21498/?add-to-cart=21498'},
#  {'Title': 'Acer Aspire 3 A315-58-33WK',
#   'Regular price': '25990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-aspire-3-a315-58-33wk/',
#   'Url cart page': 'https://clevershop.mk/product/acer-aspire-3-a315-58-33wk/?add-to-cart=21506'},
#  {'Title': 'ACER Aspire 5 (A515-56-35KA)',
#   'Regular price': '23990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-aspire-5-a515-56-35ka/',
#   'Url cart page': 'https://clevershop.mk/product/acer-aspire-5-a515-56-35ka/?add-to-cart=21693'},
#  {'Title': 'ACER ASPIRE 5 A515-45',
#   'Regular price': '29990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-aspire-5-a515-45/',
#   'Url cart page': 'https://clevershop.mk/product/acer-aspire-5-a515-45/?add-to-cart=21523'},
#  {'Title': 'Acer Aspire 5 A515-45-R07Y Silver',
#   'Regular price': '24990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-aspire-5-a515-45-r07y-silver/',
#   'Url cart page': 'https://clevershop.mk/product/acer-aspire-5-a515-45-r07y-silver/?add-to-cart=21501'},
#  {'Title': 'Acer Aspire 5 A515-45-R1FG',
#   'Regular price': '36990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-aspire-5-a515-45-r1fgnx-a7yex-005/',
#   'Url cart page': 'https://clevershop.mk/product/acer-aspire-5-a515-45-r1fgnx-a7yex-005/?add-to-cart=18324'},
#  {'Title': 'Acer Aspire 5 A515-56',
#   'Regular price': '42490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-aspire-5-a515-56-nx-a1eex-001/',
#   'Url cart page': 'https://clevershop.mk/product/acer-aspire-5-a515-56-nx-a1eex-001/?add-to-cart=18498'},
#  {'Title': 'Acer Aspire 5 A515-56-3456 Silver',
#   'Regular price': '23990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-aspire-5-a515-56-3456-silver/',
#   'Url cart page': 'https://clevershop.mk/product/acer-aspire-5-a515-56-3456-silver/?add-to-cart=21690'},
#  {'Title': 'ACER Aspire 7 (A715-41G-R24S), Black',
#   'Regular price': '42990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-aspire-7-a715-41g-r24s-black/',
#   'Url cart page': 'https://clevershop.mk/product/acer-aspire-7-a715-41g-r24s-black/?add-to-cart=21695'},
#  {'Title': 'Acer Aspire 7 A715-42G-R16C',
#   'Regular price': '54490',
#   'Discount price': '48490',
#   'Url product page': 'https://clevershop.mk/product/acer-aspire-7-a715-42g-r16c-nh-qe5ex-003/',
#   'Url cart page': 'https://clevershop.mk/product/acer-aspire-7-a715-42g-r16c-nh-qe5ex-003/?add-to-cart=18506'},
#  {'Title': 'ACER ED270RPBIIPX 27′ LED VA FHD',
#   'Regular price': '14490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-ed270rpbiipx-27-led-va-fhd/',
#   'Url cart page': 'https://clevershop.mk/product/acer-ed270rpbiipx-27-led-va-fhd/?add-to-cart=21728'},
#  {'Title': 'ACER ED273BBMIIX 27′ LED VA FHD',
#   'Regular price': '11990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-ed273bbmiix-27-led-va-fhd/',
#   'Url cart page': 'https://clevershop.mk/product/acer-ed273bbmiix-27-led-va-fhd/?add-to-cart=21734'},
#  {'Title': 'ACER ED323QURABIDPX 32” LED VA WQHD',
#   'Regular price': '20990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-ed323qurabidpx-32-led-va-wqhd/',
#   'Url cart page': 'https://clevershop.mk/product/acer-ed323qurabidpx-32-led-va-wqhd/?add-to-cart=21737'},
#  {'Title': 'ACER K272HLEbid 27” LED VA FHD',
#   'Regular price': '9690',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/21743/',
#   'Url cart page': 'https://clevershop.mk/product/21743/?add-to-cart=21743'},
#  {'Title': 'ACER LED 19.5”, V206HQLAB, Wide',
#   'Regular price': '5290',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-led-19-5-v206hqlab-wide/',
#   'Url cart page': 'https://clevershop.mk/product/acer-led-19-5-v206hqlab-wide/?add-to-cart=21750'},
#  {'Title': 'ACER LED, 21.5” V226HQLBbi',
#   'Regular price': '6290',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-led-21-5-v226hqlbbi/',
#   'Url cart page': 'https://clevershop.mk/product/acer-led-21-5-v226hqlbbi/?add-to-cart=21755'},
#  {'Title': 'ACER Nitro 5 (AN515-57-53A7)',
#   'Regular price': '51990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-nitro-5-an515-57-53a7/',
#   'Url cart page': 'https://clevershop.mk/product/acer-nitro-5-an515-57-53a7/?add-to-cart=21706'},
#  {'Title': 'Acer Nitro 5 (AN515-57-53AE)',
#   'Regular price': '47990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-nitro-5-an515-57/',
#   'Url cart page': 'https://clevershop.mk/product/acer-nitro-5-an515-57/?add-to-cart=21716'},
#  {'Title': 'Acer Nitro 5 (AN515-57-76C9)',
#   'Regular price': '60990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-nitro-5-an515-57-2/',
#   'Url cart page': 'https://clevershop.mk/product/acer-nitro-5-an515-57-2/?add-to-cart=21718'},
#  {'Title': 'Acer Nitro 5 Gaming AN515-45',
#   'Regular price': '71990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-nitro-5-gaming-an515-45/',
#   'Url cart page': 'https://clevershop.mk/product/acer-nitro-5-gaming-an515-45/?add-to-cart=21406'},
#  {'Title': 'Acer Nitro 5 Gaming AN515-45',
#   'Regular price': '66990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-nitro-5-gaming-an515-45-2/',
#   'Url cart page': 'https://clevershop.mk/product/acer-nitro-5-gaming-an515-45-2/?add-to-cart=21410'},
#  {'Title': 'Acer Nitro 5 Gaming AN517-41',
#   'Regular price': '73990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-nitro-5-gaming-an517-41/',
#   'Url cart page': 'https://clevershop.mk/product/acer-nitro-5-gaming-an517-41/?add-to-cart=21316'},
#  {'Title': 'ACER Nitro KG272UBMIIPX, 27″ LED IPS WQHD',
#   'Regular price': '16990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-nitro-kg272ubmiipx-27-led-ips-wqhd/',
#   'Url cart page': 'https://clevershop.mk/product/acer-nitro-kg272ubmiipx-27-led-ips-wqhd/?add-to-cart=21758'},
#  {'Title': 'Acer Nitro N50-640',
#   'Regular price': '64990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/21720/',
#   'Url cart page': 'https://clevershop.mk/product/21720/?add-to-cart=21720'},
#  {'Title': 'ACER NITRO N50-640',
#   'Regular price': '82990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-nitro-n50-640/',
#   'Url cart page': 'https://clevershop.mk/product/acer-nitro-n50-640/?add-to-cart=21726'},
#  {'Title': 'ACER Nitro VG240YBMIIX, 24″ LED IPS FHD',
#   'Regular price': '10490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-nitro-vg240ybmiix-24-led-ips-fhd/',
#   'Url cart page': 'https://clevershop.mk/product/acer-nitro-vg240ybmiix-24-led-ips-fhd/?add-to-cart=21764'},
#  {'Title': 'ACER Nitro VG270BMIIX, 27″ LED IPS FHD',
#   'Regular price': '12990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-nitro-vg270bmiix-27-led-ips-fhd/',
#   'Url cart page': 'https://clevershop.mk/product/acer-nitro-vg270bmiix-27-led-ips-fhd/?add-to-cart=21771'},
#  {'Title': 'Acer Predator Helios 300 PH315-54',
#   'Regular price': '67990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/predator-helios-300-ph315-54/',
#   'Url cart page': 'https://clevershop.mk/product/predator-helios-300-ph315-54/?add-to-cart=21392'},
#  {'Title': 'ACER Predator Helios 300 PH315-54-732Y',
#   'Regular price': '103990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-predator-helios-300-ph315-54-732y/',
#   'Url cart page': 'https://clevershop.mk/product/acer-predator-helios-300-ph315-54-732y/?add-to-cart=21403'},
#  {'Title': 'Acer Predator Helios 300 PH315-54-75YK',
#   'Regular price': '83990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-predator-helios-300-ph315-54-75yk/',
#   'Url cart page': 'https://clevershop.mk/product/acer-predator-helios-300-ph315-54-75yk/?add-to-cart=21401'},
#  {'Title': 'Acer Predator Helios 300 PH315-54-945Y',
#   'Regular price': '96990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-predator-helios-300-ph315-54-945y/',
#   'Url cart page': 'https://clevershop.mk/product/acer-predator-helios-300-ph315-54-945y/?add-to-cart=21398'},
#  {'Title': 'Acer Predator Helios 300 PH315-54-949Y',
#   'Regular price': '89990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-predator-helios-300-ph315-54-949y/',
#   'Url cart page': 'https://clevershop.mk/product/acer-predator-helios-300-ph315-54-949y/?add-to-cart=21396'},
#  {'Title': 'ACER Predator Helios 300 PH317-55-962G',
#   'Regular price': '114990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-predator-helios-300-ph317-55-962g/',
#   'Url cart page': 'https://clevershop.mk/product/acer-predator-helios-300-ph317-55-962g/?add-to-cart=21412'},
#  {'Title': 'Acer Swift 3 SF314-43',
#   'Regular price': '31990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-swift-3-sf314-43/',
#   'Url cart page': 'https://clevershop.mk/product/acer-swift-3-sf314-43/?add-to-cart=21528'},
#  {'Title': 'Acer Swift 3 SF314-43',
#   'Regular price': '34990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-swift-3-sf314-43-2/',
#   'Url cart page': 'https://clevershop.mk/product/acer-swift-3-sf314-43-2/?add-to-cart=21536'},
#  {'Title': 'ACER Swift 3 SF314-511-56XT ( Silver )',
#   'Regular price': '29990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-sf314-43-r2f9-nx-ab1ex-003/',
#   'Url cart page': 'https://clevershop.mk/product/acer-sf314-43-r2f9-nx-ab1ex-003/?add-to-cart=20829'},
#  {'Title': 'Acer Swift 3 SF314-511-56XT, Silver',
#   'Regular price': '39990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-swift-3-sf314-511-56xt-silver/',
#   'Url cart page': 'https://clevershop.mk/product/acer-swift-3-sf314-511-56xt-silver/?add-to-cart=21702'},
#  {'Title': 'Apple iPad 2020 32GB WiFi Space Gray',
#   'Regular price': '27990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/apple-ipad-2020-32gb-wifi-space-gray/',
#   'Url cart page': 'https://clevershop.mk/product/apple-ipad-2020-32gb-wifi-space-gray/?add-to-cart=17828'},
#  {'Title': 'Apple iPad Air (2020) 64GB 4GB RAM',
#   'Regular price': '39590',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/apple-ipad-air-2020-64gb-4gb-ram/',
#   'Url cart page': 'https://clevershop.mk/product/apple-ipad-air-2020-64gb-4gb-ram/?add-to-cart=18811'},
#  {'Title': 'Apple iPad Air 2020 WIFI only 256GB blue',
#   'Regular price': '51990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/apple
',
#   'Url product page': 'https://clevershop.mk/product/apple-iphone-14-pro-max-128gb-6gb-ram/',
#   'Url cart page': 'https://clevershop.mk/product/apple-iphone-14-pro-max-128gb-6gb-ram/?add-to-cart=22891'},
#  {'Title': 'Apple iPhone 14 Pro Max 256GB 6GB RAM',
#   'Regular price': '105000',
#   'Discount price': '96990',
#   'Url product page': 'https://clevershop.mk/product/apple-iphone-14-pro-max-256gb-6gb-ram/',
#   'Url cart page': 'https://clevershop.mk/product/apple-iphone-14-pro-max-256gb-6gb-ram/?add-to-cart=23600'},
#  {'Title': 'Apple iPhone SE 128GB 3GB RAM',
#   'Regular price': '29690',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/apple-iphone-se-2020-128gb-3gb-ram/',
#   'Url cart page': 'https://clevershop.mk/product/apple-iphone-se-2020-128gb-3gb-ram/?add-to-cart=18691'},
#  {'Title': 'Apple iPhone SE 64GB 3GB RAM',
#   'Regular price': '32990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/apple-iphone-se-2020-64gb-3gb-ram/',
#   'Url cart page': 'https://clevershop.mk/product/apple-iphone-se-2020-64gb-3gb-ram/?add-to-cart=18945'},
#  {'Title': 'Apple Watch Series 7',
#   'Regular price': '28990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/apple-watch-series-7/',
#   'Url cart page': 'https://clevershop.mk/product/apple-watch-series-7/?add-to-cart=19657'},
#  {'Title': 'Asus E410MA',
#   'Regular price': '10990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/asus-e410ma/',
#   'Url cart page': 'https://clevershop.mk/product/asus-e410ma/?add-to-cart=22702'},
#  {'Title': 'ASUS ROG GL531GT-XS53',
#   'Regular price': '44990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/asus-rog-gl531gt-xs53/',
#   'Url cart page': 'https://clevershop.mk/product/asus-rog-gl531gt-xs53/?add-to-cart=20931'},
#  {'Title': 'Asus ROG Strix G15 Advantage Edition G513',
#   'Regular price': '112990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/asus-rog-strix-g15-advantage-edition-g513/',
#   'Url cart page': 'https://clevershop.mk/product/asus-rog-strix-g15-advantage-edition-g513/?add-to-cart=21336'},
#  {'Title': 'Asus TUF Gaming F15 FX506LH',
#   'Regular price': '39990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/asus-tuf-gaming-f15-fx506lh/',
#   'Url cart page': 'https://clevershop.mk/product/asus-tuf-gaming-f15-fx506lh/?add-to-cart=21950'},
#  {'Title': 'ASUS TUF Gaming F17 FX706HEB',
#   'Regular price': '59990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/asus-tuf-gaming-f17-fx706heb/',
#   'Url cart page': 'https://clevershop.mk/product/asus-tuf-gaming-f17-fx706heb/?add-to-cart=20967'},
#  {'Title': 'ASUS TUF Gaming NVIDIA GeForce RTX 3070 V2 OC Edition Video Card',
#   'Regular price': '75990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/asus-tuf-gaming-nvidia-geforce-rtx-3070-v2-oc-edition-video-card/',
#   'Url cart page': 'https://clevershop.mk/product/asus-tuf-gaming-nvidia-geforce-rtx-3070-v2-oc-edition-video-card/?add-to-cart=17873'},
#  {'Title': 'DELL 23,8″ P2421D IPS LED-backlit LCD monitor',
#   'Regular price': '16590',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-238-p2421d-ips-led-backlit-lcd-monitor/',
#   'Url cart page': 'https://clevershop.mk/product/dell-238-p2421d-ips-led-backlit-lcd-monitor/?add-to-cart=17338'},
#  {'Title': 'DELL AW2521HFLA 24.5″ FHD',
#   'Regular price': '20490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-aw2521hfla-24-5-fhd/',
#   'Url cart page': 'https://clevershop.mk/product/dell-aw2521hfla-24-5-fhd/?add-to-cart=17415'},
#  {'Title': 'DELL AW2721D 27″ QHD 2560 x 1440',
#   'Regular price': '39990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-aw2721d-27-qhd-2560-x-1440/',
#   'Url cart page': 'https://clevershop.mk/product/dell-aw2721d-27-qhd-2560-x-1440/?add-to-cart=17422'},
#  {'Title': 'DELL Curved S2422HG 23.6″ VA LED-backlit LCD',
#   'Regular price': '16590',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-curved-s2422hg-23-6-va-led-backlit-lcd/',
#   'Url cart page': 'https://clevershop.mk/product/dell-curved-s2422hg-23-6-va-led-backlit-lcd/?add-to-cart=17393'},
#  {'Title': 'Dell G15 5511 Gaming Laptop',
#   'Regular price': '104990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-g15-5511-gaming-laptop/',
#   'Url cart page': 'https://clevershop.mk/product/dell-g15-5511-gaming-laptop/?add-to-cart=21340'},
#  {'Title': 'DELL Monitor E2222HS  21.5″ VA',
#   'Regular price': '9490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-monitor-e2222hs-21-5-va/',
#   'Url cart page': 'https://clevershop.mk/product/dell-monitor-e2222hs-21-5-va/?add-to-cart=17118'},
#  {'Title': 'DELL Monitor E2420HS, 23.8″ IPS Led AG',
#   'Regular price': '11690',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-monitor-e2420hs-23-8-ips-led-ag/',
#   'Url cart page': 'https://clevershop.mk/product/dell-monitor-e2420hs-23-8-ips-led-ag/?add-to-cart=17253'},
#  {'Title': 'DELL Monitor E2720H, 27.0″',
#   'Regular price': '11990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-monitor-e2720h-27-0/',
#   'Url cart page': 'https://clevershop.mk/product/dell-monitor-e2720h-27-0/?add-to-cart=17271'},
#  {'Title': 'DELL Monitor E2720HS 27.0″',
#   'Regular price': '12290',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-monitor-e2720hs-27-0-ips-led-ag/',
#   'Url cart page': 'https://clevershop.mk/product/dell-monitor-e2720hs-27-0-ips-led-ag/?add-to-cart=17260'},
#  {'Title': 'DELL Monitor P2222H, 22” Full HD',
#   'Regular price': '12290',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-monitor-p2222h-22-full-hd/',
#   'Url cart page': 'https://clevershop.mk/product/dell-monitor-p2222h-22-full-hd/?add-to-cart=17317'},
#  {'Title': 'DELL Monitor S2721HS, 27″, IPS LED-backlit LCD',
#   'Regular price': '14490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-monitor-s2721hs-27-ips-led-backlit-lcd/',
#   'Url cart page': 'https://clevershop.mk/product/dell-monitor-s2721hs-27-ips-led-backlit-lcd/?add-to-cart=17291'},
#  {'Title': 'DELL Monitor SE2422H 23.8″',
#   'Regular price': '8890',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-monitor-se2422h-23-8/',
#   'Url cart page': 'https://clevershop.mk/product/dell-monitor-se2422h-23-8/?add-to-cart=17277'},
#  {'Title': 'DELL Monitor SE2722H, 27″ VA LED-backlit LCD',
#   'Regular price': '10990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-monitor-se2722h-27-va-led-backlit-lcd/',
#   'Url cart page': 'https://clevershop.mk/product/dell-monitor-se2722h-27-va-led-backlit-lcd/?add-to-cart=17283'},
#  {'Title': 'DELL Monitor Video Conferencing S2422HZ, 24″ IPS LED-backlit LCD',
#   'Regular price': '20990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-monitor-video-conferencing-s2422hz-24-ips-led-backlit-lcd/',
#   'Url cart page': 'https://clevershop.mk/product/dell-monitor-video-conferencing-s2422hz-24-ips-led-backlit-lcd/?add-to-cart=17301'},
#  {'Title': 'DELL Monitor Video Conferencing S2722DZ, 27″ IPS WLED-backlit LCD',
#   'Regular price': '27590',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-monitor-video-conferencing-s2722dz-27-ips-wled-backlit-lcd/',
#   'Url cart page': 'https://clevershop.mk/product/dell-monitor-video-conferencing-s2722dz-27-ips-wled-backlit-lcd/?add-to-cart=17310'},
#  {'Title': 'DELL NB Latitude 5420,11th.Gen.Intel Core i5-1145G7(4 Core,8M cache,2.6GHz to 4.4GHz,vPro),14.0″ FHD(1920×1080)AG 250nits,16GB DDR4 non-ECC Memory,512GB M.2 PCIe NVMe Class 35 SSD,Intel Iris Xe Graphics,TB4,Wi-Fi6,BT5.1,Bckl Kb,4Cell,Win10Pro,3Y',
#   'Regular price': '71990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-nb-latitude-542011th-gen-intel-core-i5-1145g74-core8m-cache2-6ghz-to-4-4ghzvpro14-0-fhd1920x1080ag-250nits16gb-ddr4-non-ecc-memory512gb-m-2-pcie-nvme-class-35-ssdintel-iris-xe-graph/',
#   'Url cart page': 'https://clevershop.mk/product/dell-nb-latitude-542011th-gen-intel-core-i5-1145g74-core8m-cache2-6ghz-to-4-4ghzvpro14-0-fhd1920x1080ag-250nits16gb-ddr4-non-ecc-memory512gb-m-2-pcie-nvme-class-35-ssdintel-iris-xe-graph/?add-to-cart=23124'},
#  {'Title': 'DELL NB Latitude 5420,11th.Gen.Intel Core i5-1145G7(4 Core,8M cache,2.6GHz to 4.4GHz,vPro),14.0″ FHD(1920×1080)AG 250nits,16GB DDR4 non-ECC Memory,512GB M.2 PCIe NVMe Class 35 SSD,Intel Iris Xe Graphics,TB4
',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-pc-optiplex-3050-mt-intel-core-i3-7100/',
#   'Url cart page': 'https://clevershop.mk/product/dell-pc-optiplex-3050-mt-intel-core-i3-7100/?add-to-cart=17438'},
#  {'Title': 'Dell PC OptiPlex 3080 SFF, Intel Core i5-10505',
#   'Regular price': '40890',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-pc-optiplex-3080-sff-intel-core-i5-10505/',
#   'Url cart page': 'https://clevershop.mk/product/dell-pc-optiplex-3080-sff-intel-core-i5-10505/?add-to-cart=17444'},
#  {'Title': 'DELL PC OptiPlex 3090 SFF, Intel Core i5-10505',
#   'Regular price': '41990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-pc-optiplex-3090-sff-intel-core-i5-10505-6-cores-12mb-12t-3-2ghz-to-4-6ghz-65w-8gb1x8gb-ddr4-256gb-m-2-pcie-nvme-class-35-ssd-intel-integrated-graphics-dvd-rw-dp-hdmi-2-0-ms116-mous/',
#   'Url cart page': 'https://clevershop.mk/product/dell-pc-optiplex-3090-sff-intel-core-i5-10505-6-cores-12mb-12t-3-2ghz-to-4-6ghz-65w-8gb1x8gb-ddr4-256gb-m-2-pcie-nvme-class-35-ssd-intel-integrated-graphics-dvd-rw-dp-hdmi-2-0-ms116-mous/?add-to-cart=23140'},
#  {'Title': 'DELL S2421HGF 23,8″ TN LED-backlit LCD',
#   'Regular price': '14490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-s2421hgf-238-tn-led-backlit-lcd/',
#   'Url cart page': 'https://clevershop.mk/product/dell-s2421hgf-238-tn-led-backlit-lcd/?add-to-cart=17386'},
#  {'Title': 'DELL S2522HG 24.5″ Fast IPS LED-backlit LCD',
#   'Regular price': '18690',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-s2522hg-24-5-fast-ips-led-backlit-lcd/',
#   'Url cart page': 'https://clevershop.mk/product/dell-s2522hg-24-5-fast-ips-led-backlit-lcd/?add-to-cart=17400'},
#  {'Title': 'DELL S2721HGF 27″ VA LED-backlit LCD',
#   'Regular price': '17590',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-s2721hgf-27-va-led-backlit-lcd/',
#   'Url cart page': 'https://clevershop.mk/product/dell-s2721hgf-27-va-led-backlit-lcd/?add-to-cart=17407'},
#  {'Title': 'DELL U2421E 24,1″ IPS LED-backlit LCD',
#   'Regular price': '20490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-u2421e-241-ips-led-backlit-lcd/',
#   'Url cart page': 'https://clevershop.mk/product/dell-u2421e-241-ips-led-backlit-lcd/?add-to-cart=17358'},
#  {'Title': 'DELL U2422H 23.8″ IPS WLED-backlit LCD',
#   'Regular price': '16590',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-u2422h-23-8-ips-wled-backlit-lcd/',
#   'Url cart page': 'https://clevershop.mk/product/dell-u2422h-23-8-ips-wled-backlit-lcd/?add-to-cart=17366'},
#  {'Title': 'DELL U2722D 27″ IPS LED-backlit LCD',
#   'Regular price': '29990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-u2722d-27-ips-led-backlit-lcd/',
#   'Url cart page': 'https://clevershop.mk/product/dell-u2722d-27-ips-led-backlit-lcd/?add-to-cart=17373'},
#  {'Title': 'DELL Vostro 3510',
#   'Regular price': '43990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-vostro-3510/',
#   'Url cart page': 'https://clevershop.mk/product/dell-vostro-3510/?add-to-cart=21084'},
#  {'Title': 'Epson L1110 Inkjet w/ Eco Tank System (CISS)',
#   'Regular price': '8190',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/epson-l1110-inkjet-w-eco-tank-system-ciss/',
#   'Url cart page': 'https://clevershop.mk/product/epson-l1110-inkjet-w-eco-tank-system-ciss/?add-to-cart=19879'},
#  {'Title': 'Epson L1300 InkJet A3+ CISS System',
#   'Regular price': '32350',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/epson-l1300-inkjet-a3-ciss-system/',
#   'Url cart page': 'https://clevershop.mk/product/epson-l1300-inkjet-a3-ciss-system/?add-to-cart=19983'},
#  {'Title': 'Epson L14150 Inkjet A3+ MFP LAN/WiFI w/ EcoTank System (CISS)',
#   'Regular price': '32590',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/epson-l14150-inkjet-a3-mfp-lan-wifi-w-ecotank-system-ciss/',
#   'Url cart page': 'https://clevershop.mk/product/epson-l14150-inkjet-a3-mfp-lan-wifi-w-ecotank-system-ciss/?add-to-cart=19991'},
#  {'Title': 'Epson L15160 MFP A3+ EcoTank System',
#   'Regular price': '67190',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/epson-l15160-mfp-a3-ecotank-system/',
#   'Url cart page': 'https://clevershop.mk/product/epson-l15160-mfp-a3-ecotank-system/?add-to-cart=19999'},
#  {'Title': 'Epson L1800 A3+ Photo CISS System',
#   'Regular price': '37590',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/epson-l1800-a3-photo-ciss-system/',
#   'Url cart page': 'https://clevershop.mk/product/epson-l1800-a3-photo-ciss-system/?add-to-cart=19996'},
#  {'Title': 'Epson L3211 Inkjet w/ Eco Tank System (CISS) MFP Printer',
#   'Regular price': '11390',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/epson-l3211-inkjet-w-eco-tank-system-ciss-mfp-printer/',
#   'Url cart page': 'https://clevershop.mk/product/epson-l3211-inkjet-w-eco-tank-system-ciss-mfp-printer/?add-to-cart=19882'},
#  {'Title': 'Epson L3251 Inkjet w/ Eco Tank System (CISS) MFP WiFi Direct',
#   'Regular price': '12490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/epson-l3251-inkjet-w-eco-tank-system-ciss-mfp-wifi-direct/',
#   'Url cart page': 'https://clevershop.mk/product/epson-l3251-inkjet-w-eco-tank-system-ciss-mfp-wifi-direct/?add-to-cart=19885'},
#  {'Title': 'Epson L5290 Inkjet w/ INK Tank System (CISS) MFP Fax/WiFi/LAN',
#   'Regular price': '17490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/epson-l5290-inkjet-w-ink-tank-system-ciss-mfp-fax-wifi-lan/',
#   'Url cart page': 'https://clevershop.mk/product/epson-l5290-inkjet-w-ink-tank-system-ciss-mfp-fax-wifi-lan/?add-to-cart=19888'},
#  {'Title': 'EPSON L805 Inkjet Photo w/ Ink Tank System (CISS)',
#   'Regular price': '20990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/epson-l805-inkjet-photo-w-ink-tank-system-ciss/',
#   'Url cart page': 'https://clevershop.mk/product/epson-l805-inkjet-photo-w-ink-tank-system-ciss/?add-to-cart=19628'},
#  {'Title': 'EPSON LQ-350+ kirilica',
#   'Regular price': '19590',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/epson-lq-350-kirilica/',
#   'Url cart page': 'https://clevershop.mk/product/epson-lq-350-kirilica/?add-to-cart=19894'},
#  {'Title': 'EPSON LX-350+ kirilica',
#   'Regular price': '18990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/epson-lx-350-kirilica/',
#   'Url cart page': 'https://clevershop.mk/product/epson-lx-350-kirilica/?add-to-cart=19891'},
#  {'Title': 'EVGA GeForce GT 1030 SC 2GB 64-Bit GDDR5',
#   'Regular price': '10990',
#   'Discount price': '9990',
#   'Url product page': 'https://clevershop.mk/product/evga-geforce-gt-1030-sc-2gb-64-bit-gddr5/',
#   'Url cart page': 'https://clevershop.mk/product/evga-geforce-gt-1030-sc-2gb-64-bit-gddr5/?add-to-cart=17841'},
#  {'Title': 'Evolve III Maestro E-Book 11.6″',
#   'Regular price': '7990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/evolve-iii-maestro-e-book-11-6/',
#   'Url cart page': 'https://clevershop.mk/product/evolve-iii-maestro-e-book-11-6/?add-to-cart=20308'},
#  {'Title': 'Gateway GWNC31514',
#   'Regular price': '19990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/gateway-gwnc31514/',
#   'Url cart page': 'https://clevershop.mk/product/gateway-gwnc31514/?add-to-cart=21184'},
#  {'Title': 'Gateway GWTN156-11BK',
#   'Regular price': '12990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/gateway-gwtn156-11bk/',
#   'Url cart page': 'https://clevershop.mk/product/gateway-gwtn156-11bk/?add-to-cart=22713'},
#  {'Title': 'Gigabyte GeForce RTX 3090 Turbo GDDR6X Graphics Card *High Hash Rate',
#   'Regular price': '199900',
#   'Discount price': '189990',
#   'Url product page': 'https://clevershop.mk/product/gigabyte-geforce-rtx-3090-turbo-gddr6x-graphics-card-high-hash-rate/',
#   'Url cart page': 'https://clevershop.mk/product/gigabyte-geforce-rtx-3090-turbo-gddr6x-graphics-card-high-hash-rate/?add-to-cart=17896'},
#  {'Title': 'GIGABYTE GeForce RTX™ 3080 GAMING OC 10G (rev. 2.0)',
#   'Regular price': '117900',
#   'Discount price': '109990',
#   'Url product page': 'https://clevershop.mk/product/geforce-rtx-3080-gaming-oc-10g-rev-2-0/',
#   'Url cart page': 'https://clevershop.mk/product/geforce-rtx-3080-gaming-oc-10g-rev-2-0/?add-to-cart=17886'},
#  {'Title': 'Google Pixel 6 128GB 8GB RAM',
#   'Regular price': '47990',
#   'Discount price': '43990',
#   'Url product page': 'https://clevershop.mk/product/google-pixel-6/',
#   'Url cart page': 'https://clevershop.mk/product/google-pixel-6/?add-to-cart=18625'},
#  {'Title': 'Google Pixel 6 Pro 256GB 12GB',
#   'Regular price': '69990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/google-pixel-6-pro-256gb-12gb/',
#   'Url cart page': 'https://clevershop.mk/product/google-pixel-6-pro-256gb-12gb/?add-to-cart=18630'},
#  {'Title': 'HP 14-DQ0031',
#   'Regular price': '12990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-14-dq0031/',
#   'Url cart page': 'https://clevershop.mk/product/hp-14-dq0031/?add-to-cart=20957'},
#  {'Title': 'HP 15-DW3138NIA',
#   'Regular price': '28990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-15-dw3138nia/',
#   'Url cart page': 'https://clevershop.mk/product/hp-15-dw3138nia/?add-to-cart=21579'},
#  {'Title': 'HP 15-dw3142nia',
#   'Regular price': '40490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-15-dw3142nia/',
#   'Url cart page': 'https://clevershop.mk/product/hp-15-dw3142nia/?add-to-cart=21585'},
#  {'Title': 'HP 15s-eq2382nia',
#   'Regular price': '32990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-15s-eq2382nia/',
#   'Url cart page': 'https://clevershop.mk/product/hp-15s-eq2382nia/?add-to-cart=21582'},
#  {'Title': 'HP 250 G8 2X7T8EA',
#   'Regular price': '18990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-250-g8-2x7t8ea/',
#   'Url cart page': 'https://clevershop.mk/product/hp-250-g8-2x7t8ea/?add-to-cart=18333'},
#  {'Title': 'HP 250 G8, 2W8Z6EA',
#   'Regular price': '22990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-250-g8-2w8z6ea/',
#   'Url cart page': 'https://clevershop.mk/product/hp-250-g8-2w8z6ea/?add-to-cart=21557'},
#  {'Title': 'HP 250 G8, 2X7W8EA',
#   'Regular price': '16990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-250-g8-2x7w8ea/',
#   'Url cart page': 'https://clevershop.mk/product/hp-250-g8-2x7w8ea/?add-to-cart=21548'},
#  {'Title': 'HP 255 G8, 27K51EA',
#   'Regular price': '22990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-255-g8-27k51ea/',
#   'Url cart page': 'https://clevershop.mk/product/hp-255-g8-27k51ea/?add-to-cart=18512'},
#  {'Title': 'HP 255 G8, 3V5K4EA',
#   'Regular price': '24990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-255-g8-3v5k4ea/',
#   'Url cart page': 'https://clevershop.mk/product/hp-255-g8-3v5k4ea/?add-to-cart=21565'},
#  {'Title': 'HP Color Laser 150a',
#   'Regular price': '10580',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-printer-color-laser-150a/',
#   'Url cart page': 'https://clevershop.mk/product/hp-printer-color-laser-150a/?add-to-cart=17631'},
#  {'Title': 'HP ENVY 13-BA1053NN',
#   'Regular price': '55990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-envy-13-ba1053nn/',
#   'Url cart page': 'https://clevershop.mk/product/hp-envy-13-ba1053nn/?add-to-cart=21591'},
#  {'Title': 'HP ENVY X360 13-AY1007NN',
#   'Regular price': '59990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-envy-x360-13-ay1007nn/',
#   'Url cart page': 'https://clevershop.mk/product/hp-envy-x360-13-ay1007nn/?add-to-cart=21598'},
#  {'Title': 'HP Laptop 14-dq0001dx',
#   'Regular price': '13990',
#   'Discount price': '12490',
#   'Url product page': 'https://clevershop.mk/product/hp-laptop-14-dq0001dx/',
#   'Url cart page': 'https://clevershop.mk/product/hp-laptop-14-dq0001dx/?add-to-cart=21192'},
#  {'Title': 'HP LAPTOP 15S-FQ2002NIA',
#   'Regular price': '31990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-laptop-15s-fq2002nia/',
#   'Url cart page': 'https://clevershop.mk/product/hp-laptop-15s-fq2002nia/?add-to-cart=21572'},
#  {'Title': 'HP LAPTOP 15S-FQ2003NIA',
#   'Regular price': '29990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-laptop-15s-fq2003nia/',
#   'Url cart page': 'https://clevershop.mk/product/hp-laptop-15s-fq2003nia/?add-to-cart=21575'},
#  {'Title': 'HP Laptop 15s-fq3000na',
#   'Regular price': '21990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-laptop-15s-fq3000na/',
#   'Url cart page': 'https://clevershop.mk/product/hp-laptop-15s-fq3000na/?add-to-cart=18348'},
#  {'Title': 'HP Laptop 15s-fq3001na',
#   'Regular price': '17990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/18341/',
#   'Url cart page': 'https://clevershop.mk/product/18341/?add-to-cart=18341'},
#  {'Title': 'HP LaserJet Pro M404dn',
#   'Regular price': '15490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-printer-laserjet-pro-m404dn/',
#   'Url cart page': 'https://clevershop.mk/product/hp-printer-laserjet-pro-m404dn/?add-to-cart=17628'},
#  {'Title': 'HP LaserJet Pro MFP M428fdw',
#   'Regular price': '28790',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-printer-mfp-laserjet-pro-m428fdw/',
#   'Url cart page': 'https://clevershop.mk/product/hp-printer-mfp-laserjet-pro-m428fdw/?add-to-cart=17734'},
#  {'Title': 'HP MLJ M236dw, 9YF95A мултифункциски ласерски принтер',
#   'Regular price': '11990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-mlj-m236dw-9yf95a-%d0%bc%d1%83%d0%bb%d1%82%d0%b8%d1%84%d1%83%d0%bd%d0%ba%d1%86%d0%b8%d1%81%d0%ba%d0%b8-%d0%bb%d0%b0%d1%81%d0%b5%d1%80%d1%81%d0%ba%d0%b8-%d0%bf%d1%80%d0%b8%d0%bd%d1%82%d0%b5%d1%80/',
# ...
#   'Url cart page': 'https://clevershop.mk/product/notebook-acer-swift-1-sf114-33-p3ee-silver-14-fhd-ips-intel-pentium-silver-processor-n5030-8gb-ddr4-256gb-nvme-ssd-4xusb-figerprint-camera-hdmi-bt-linux/?add-to-cart=16939'},
#  {'Title': 'ACER Swift 1 (SF114-33-P629), Gold',
#   'Regular price': '27990',
#   'Discount price': '21990',
#   'Url product page': 'https://clevershop.mk/product/acer-swift-1-sf114-33-p629-gold-14-fhd-ips-intel-pentium-silver-processor-n5030-8gb-ddr4-256gb-nvme-ssd-4xusb-figerprint-camera-hdmi-bt-linux/',
#   'Url cart page': 'https://clevershop.mk/product/acer-swift-1-sf114-33-p629-gold-14-fhd-ips-intel-pentium-silver-processor-n5030-8gb-ddr4-256gb-nvme-ssd-4xusb-figerprint-camera-hdmi-bt-linux/?add-to-cart=16946'},
#  {'Title': 'ACER SWiIFT 3, SF314-511-56XT, Silver, 14” FHD, Intel® Core™ i5-1135G7, 16G DDR4, 512GB SSD, 1xUSB Type-C / Thunderbolt™ 4, 1xUSB 3.2, Figerprint, Camera, HDMI,  BT, Linux',
#   'Regular price': '44990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-swiift-3-sf314-511-56xt-silver-14-fhd-intel-core-i5-1135g7-16g-ddr4-512gb-ssd-1xusb-type-c-thunderbolt-4-1xusb-3-2-figerprint-camera-hdmi-bt-linux/',
#   'Url cart page': 'https://clevershop.mk/product/acer-swiift-3-sf314-511-56xt-silver-14-fhd-intel-core-i5-1135g7-16g-ddr4-512gb-ssd-1xusb-type-c-thunderbolt-4-1xusb-3-2-figerprint-camera-hdmi-bt-linux/?add-to-cart=16978'},
#  {'Title': 'Asus VivoBook X413JA-211.VBWB',
#   'Regular price': '25990',
#   'Discount price': '19990',
#   'Url product page': 'https://clevershop.mk/product/asus-vivobook-x413ja-211-vbwb/',
#   'Url cart page': 'https://clevershop.mk/product/asus-vivobook-x413ja-211-vbwb/?add-to-cart=12999'},
#  {'Title': 'DELL NB Latitude 5520, 11th Intel Core i5-1135G7 (4C/8T/8MB/2.4GHz), 15.6″ FHD (1920×1080) 250nits, 8GB DDR4, M.2 256GB PCIe NVMe, FPR Reader, SmartCard Reader, TB4, Cam+Mic, 4Cell 63WHr, 65W Type-C, AX201+BT5.1, WLAN/WWAN, Backlit kbd, Win10Pro, 3Y',
#   'Regular price': '62690',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-nb-latitude-5520-11th-intel-core-i5-1135g7-4c-8t-8mb-2-4ghz-15-6-fhd-1920x1080-250nits-8gb-ddr4-m-2-256gb-pcie-nvme-fpr-reader-smartcard-reader-tb4-cammic-4cell-63whr-65w-type-c/',
#   'Url cart page': 'https://clevershop.mk/product/dell-nb-latitude-5520-11th-intel-core-i5-1135g7-4c-8t-8mb-2-4ghz-15-6-fhd-1920x1080-250nits-8gb-ddr4-m-2-256gb-pcie-nvme-fpr-reader-smartcard-reader-tb4-cammic-4cell-63whr-65w-type-c/?add-to-cart=17156'},
#  {'Title': 'DELL NB Vostro 3515, AMD Ryzen™ 3 3250U (2 Core,4M cache,2.6GHz to 3.5GHz), 15.6″ FHD(1920×1080) WVA AG 220 nits, 8GB(1x8GB) DDR4, 256GB M.2 PCIe NVMe SSD, Integrated graphics with AMD APU, Wi-Fi, BT5.0, Bckl Kb, 3-Cell, Ubuntu 20.04, Carbon Black,3Y',
#   'Regular price': '27990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/dell-nb
#  {'Title': 'Tablet PC, Veidoo 10 Inch Android Tablet, 10.1 inch IPS Screen, Dual Camera, WiFi/GPS/OTG/Bluetooth, 3G Phone Call Dual SIM Card Slots, 2GB RAM, 32GB Storage, 5000mAh Battery',
#   'Regular price': '5990',
#   'Discount price': '5290',
#   'Url product page': 'https://clevershop.mk/product/tablet-pc-veidoo-10-inch-android-tablet-10-1-inch-ips-screen-dual-camera-wifi-gps-otg-bluetooth-3g-phone-call-dual-sim-card-slots-2gb-ram-32gb-storage-5000mah-battery/',
#   'Url cart page': 'https://clevershop.mk/product/tablet-pc-veidoo-10-inch-android-tablet-10-1-inch-ips-screen-dual-camera-wifi-gps-otg-bluetooth-3g-phone-call-dual-sim-card-slots-2gb-ram-32gb-storage-5000mah-battery/?add-to-cart=13085'},
#  {'Title': 'FS200 Mini Portable SSD – USB3.1',
#   'Regular price': '999',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/fs200-mini-portable-ssd-usb3-1/',
#   'Url cart page': 'https://clevershop.mk/product/fs200-mini-portable-ssd-usb3-1/https://clevershop.mk/product/fs200-mini-portable-ssd-usb3-1/'},
#  {'Title': 'G2590FX 24.5″ TN 144Hz 1920 x 1080',
#   'Regular price': '11490',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/g2590fx-24-5-tn-1920-x-1080-144hz/',
#   'Url cart page': 'https://clevershop.mk/product/g2590fx-24-5-tn-1920-x-1080-144hz/?add-to-cart=12166'},
#  {'Title': 'HP 27″ 3WL54AA QHD 144 Hz 2560 x 1440',
#   'Regular price': '21090',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-27%e2%80%b3-3wl54aa-qhd-144-hz-2560-x-1440/',
#   'Url cart page': 'https://clevershop.mk/product/hp-27%e2%80%b3-3wl54aa-qhd-144-hz-2560-x-1440/?add-to-cart=12311'},
#  {'Title': 'HP OMEN X gaming display 25″, 4WH47AA',
#   'Regular price': '17990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-omen-x-gaming-display-25-4wh47aa/',
#   'Url cart page': 'https://clevershop.mk/product/hp-omen-x-gaming-display-25-4wh47aa/?add-to-cart=12413'},
#  {'Title': 'Lemfo LEM1995 SMART женска бразлетна',
#   'Regular price': '1990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/lemfo-lem1995-smart-%d0%b6%d0%b5%d0%bd%d1%81%d0%ba%d0%b0-%d0%b1%d1%80%d0%b0%d0%b7%d0%bb%d0%b5%d1%82%d0%bd%d0%b0/',
#   'Url cart page': 'https://clevershop.mk/product/lemfo-lem1995-smart-%d0%b6%d0%b5%d0%bd%d1%81%d0%ba%d0%b0-%d0%b1%d1%80%d0%b0%d0%b7%d0%bb%d0%b5%d1%82%d0%bd%d0%b0/?add-to-cart=11279'},
#  {'Title': 'LG 27” QHD Ergo IPS Monitor with USB Type-C™',
#   'Regular price': '23990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/lg-27-qhd-ergo-ips-monitor-with-usb-type-c/',
#   'Url cart page': 'https://clevershop.mk/product/lg-27-qhd-ergo-ips-monitor-with-usb-type-c/?add-to-cart=12561'},
#  {'Title': 'MON 15.6 AOC I1601FWUX',
#   'Regular price': '10990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/mon-15-6-aoc-i1601fwux/',
#   'Url cart page': 'https://clevershop.mk/product/mon-15-6-aoc-i1601fwux/?add-to-cart=12599'},
#  {'Title': 'MON 24 ASUS VG249Q FHD IPS Gaming 144Hz HDMI DP FreeSync',
#   'Regular price': '14990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product
',
#   'Url cart page': 'https://clevershop.mk/product/acer-nitro-xv240y-pbmiiprx-23-8-led-ips-fhd-165hz-min-01ms-gtog-10001-250nits/?add-to-cart=17051'},
#  {'Title': 'ACER Nitro XV252QZBMIIPRX 24.5″ LED IPS FHD, up to 280Hz, min 0,5ms (GtoG) 1000:1 400nits HDMI DP Height adj. Pivot  Black',
#   'Regular price': '18790',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-nitro-xv252qzbmiiprx-24-5-led-ips-fhd-up-to-280hz-min-05ms-gtog-10001-400nits-hdmi-dp-height-adj-pivot-black/',
#   'Url cart page': 'https://clevershop.mk/product/acer-nitro-xv252qzbmiiprx-24-5-led-ips-fhd-up-to-280hz-min-05ms-gtog-10001-400nits-hdmi-dp-height-adj-pivot-black/?add-to-cart=17011'},
#  {'Title': 'ACER R270SI  27” LED IPS FHD, ZeroFrame, 1ms VRB, Flicker-less,1000:1, 250nits, HDMI, Black',
#   'Regular price': '9890',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-r270si-27-led-ips-fhd-zeroframe-1ms-vrb-flicker-less10001-250nits-hdmi-black/',
#   'Url cart page': 'https://clevershop.mk/product/acer-r270si-27-led-ips-fhd-zeroframe-1ms-vrb-flicker-less10001-250nits-hdmi-black/?add-to-cart=17019'},
#  {'Title': 'ACER V277BIP 27” LED IPS FHD, ZeroFrame, 4ms, Flicker-less,1000:1, 250nits, HDMI, DP, Black',
#   'Regular price': '9390',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/acer-v277bip-27-led-ips-fhd-zeroframe-4ms-flicker-less10001-250nits-hdmi-dp-black/',
#   'Url cart page': 'https://clevershop.mk/product/acer-v277bip-27-led-ips-fhd-zeroframe-4ms-flicker-less10001-250nits-hdmi-dp-black/?add-to-cart=17026'},
#  {'Title': 'MON 27 AOC AG273QCX',
#   'Regular price': '27190',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/mon-15-6-aoc-i1601fwux-copy/',
#   'Url cart page': 'https://clevershop.mk/product/mon-15-6-aoc-i1601fwux-copy/?add-to-cart=12646'},
#  {'Title': 'MON 27 LG 27GN850-B QHD IPS 1MS 144HZ HDMI',
#   'Regular price': '29990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/mon-27-lg-27gn850-b-qhd-ips-1ms-144hz-hdmi/',
#   'Url cart page': 'https://clevershop.mk/product/mon-27-lg-27gn850-b-qhd-ips-1ms-144hz-hdmi/?add-to-cart=12543'},
#  {'Title': 'MON 27 Philips 272B7QUPBEB/00 with USB-C Dock',
#   'Regular price': '20590',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/mon-27-philips-272b7qupbeb-00-with-usb-c-dock/',
#   'Url cart page': 'https://clevershop.mk/product/mon-27-philips-272b7qupbeb-00-with-usb-c-dock/?add-to-cart=12619'},
#  {'Title': 'MON 27 Philips 272V8A/00',
#   'Regular price': '10590',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/mon-27-philips-272v8a-00/',
#   'Url cart page': 'https://clevershop.mk/product/mon-27-philips-272v8a-00/?add-to-cart=12638'},
#  {'Title': 'Monitor 27 Philips 272E1GAJ/00 VA 1ms 144Hz',
#   'Regular price': '12890',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/monitor-27-philips-272e1gaj-00-va-1ms-144hz/',
#   'Url cart page': 'https://clevershop.mk/product/monitor-27-philips-272e1gaj-00-va-1ms-144hz/?add-to-cart=12618'},
#  {'Title': 'Philips 24″ 243V7QDSB',
#   'Regular price': '8390',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/philips-24%e2%80%b3-243v7qdsb/',
#   'Url cart page': 'https://clevershop.mk/product/philips-24%e2%80%b3-243v7qdsb/?add-to-cart=12396'},
#  {'Title': 'Philips 27″ 278E1A/00 4K UHD IPS',
#   'Regular price': '18990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/hp-27%e2%80%b3-278e1a-00-4k-uhd-ips/',
#   'Url cart page': 'https://clevershop.mk/product/hp-27%e2%80%b3-278e1a-00-4k-uhd-ips/?add-to-cart=12218'},
#  {'Title': 'Philips 279C9-00 MON LED 27″ 3840 x 2160 5Ms 60Hz 4K UHD',
#   'Regular price': '26990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/philips-279c9-00-mon-led-27-3840-x-2160-5ms-60hz-4k-uhd/',
#   'Url cart page': 'https://clevershop.mk/product/philips-279c9-00-mon-led-27-3840-x-2160-5ms-60hz-4k-uhd/?add-to-cart=12578'},
#  {'Title': 'Xiaomi Redmi AirDots Wireless',
#   'Regular price': '990',
#   'Discount price': None,
#   'Url product page': 'https://clevershop.mk/product/redmi-headphones/',
#   'Url cart page': 'https://clevershop.mk/product/redmi-headphones/?add-to-cart=10663'}]

# %% [markdown]
# ### Create a pandas DataFrame with the scraped products

# %%
df=pd.DataFrame(products_on_all_pages)
df
# Out:
#                                                  Title Regular price  \
# 0                                    Acer A315-23-A7KD         17590
# 1                                    Acer A315-23-R5P2         27490
# 2                                ACER Aspire 1 A115-22         18999
# 3                           Acer Aspire 3 A315-23-R26A         29990
# 4                           Acer Aspire 3 A315-58-33WK         24490
# ..                                                 ...           ...
# 315        Monitor 27 Philips 272E1GAJ/00 VA 1ms 144Hz         12890
# 316                              Philips 24″ 243V7QDSB          8390
# 317                   Philips 27″ 278E1A/00 4K UHD IPS         18990
# 318  Philips 279C9-00 MON LED 27″ 3840 x 2160 5Ms 6...         26990
# 319                      Xiaomi Redmi AirDots Wireless           990
#
#     Discount price                                   Url product page  \
# 0             None   https://clevershop.mk/product/acer-a315-23-a7kd/
# 1             None   https://clevershop.mk/product/acer-a315-23-r5p2/
# 2            15999  https://clevershop.mk/product/acer-aspire-1-nx...
# 3             None  https://clevershop.mk/product/acer-aspire-3-a3...
# 4             None               https://clevershop.mk/product/21498/
# ..             ...                                                ...
# 315           None  https://clevershop.mk/product/monitor-27-phili...
# 316           None  https://clevershop.mk/product/philips-24%e2%80...
# 317           None  https://clevershop.mk/product/hp-27%e2%80%b3-2...
# 318           None  https://clevershop.mk/product/philips-279c9-00...
# 319           None    https://clevershop.mk/product/redmi-headphones/
#
#                                          Url cart page
# 0    https://clevershop.mk/product/acer-a315-23-a7k...
# 1    https://clevershop.mk/product/acer-a315-23-r5p...
# 2    https://clevershop.mk/product/acer-aspire-1-nx...
# 3    https://clevershop.mk/product/acer-aspire-3-a3...
# 4    https://clevershop.mk/product/21498/?add-to-ca...
# ..                                                 ...
# 315  https://clevershop.mk/product/monitor-27-phili...
# 316  https://clevershop.mk/product/philips-24%e2%80...
# 317  https://clevershop.mk/product/hp-27%e2%80%b3-2...
# 318  https://clevershop.mk/product/philips-279c9-00...
# 319  https://clevershop.mk/product/redmi-headphones...
#
# [320 rows x 5 columns]

# %% [markdown]
# Save the dataframe as `.csv`

# %%
df.to_csv("products.csv",index=False)
