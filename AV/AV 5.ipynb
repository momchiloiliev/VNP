# %% [markdown]
# ## AV 5 Classification

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('user_behavior_dataset.csv')

# %% [markdown]
# #### Data analysis

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# 2                        32                  322   42    Male
# 3                        56                  871   20    Male
# 4                        58                  988   31  Female
#
#    User Behavior Class
# 0                    4
# 1                    3
# 2                    2
# 3                    3
# 4                    3

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'User ID'}>,
#         <Axes: title={'center': 'App Usage Time (min/day)'}>,
#         <Axes: title={'center': 'Screen On Time (hours/day)'}>],
#        [<Axes: title={'center': 'Battery Drain (mAh/day)'}>,
#         <Axes: title={'center': 'Number of Apps Installed'}>,
#         <Axes: title={'center': 'Data Usage (MB/day)'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'User Behavior Class'}>, <Axes: >]],
#       dtype=object)

# %%
fig = plt.figure(8)
i =1
j=1
k=1
s=1
for column in df.columns:
    fig.subplots_adjust(i,j,k,s)
    fig.show(df[column].hist())
    i+=1
    j+=1
    k+=1
    s+=1

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# 2                        32                  322   42    Male
# 3                        56                  871   20    Male
# 4                        58                  988   31  Female
#
#    User Behavior Class
# 0                    4
# 1                    3
# 2                    2
# 3                    3
# 4                    3

# %%
encoder = LabelEncoder()
df.Gender = encoder.fit_transform(df.Gender)

# %%
encoder.classes_
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Device Model'] = encoder.fit_transform(df['Device Model'])
df['Operating System'] = encoder.fit_transform(df['Operating System'])

# %%
encoder.classes_
# Out:
# array(['Android', 'iOS'], dtype=object)

# %%
df.drop(['User Behavior Class'],axis=1)
# Out:
#      User ID  Device Model  Operating System  App Usage Time (min/day)  \
# 0          1             0                 0                       393
# 1          2             1                 0                       268
# 2          3             3                 0                       154
# 3          4             0                 0                       239
# 4          5             4                 1                       187
# ..       ...           ...               ...                       ...
# 695      696             4                 1                        92
# 696      697             3                 0                       316
# 697      698             0                 0                        99
# 698      699             2                 0                        62
# 699      700             1                 0                       212
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                           6.4                     1872
# 1                           4.7                     1331
# 2                           4.0                      761
# 3                           4.8                     1676
# 4                           4.3                     1367
# ..                          ...                      ...
# 695                         3.9                     1082
# 696                         6.8                     1965
# 697                         3.1                      942
# 698                         1.7                      431
# 699                         5.4                     1306
#
#      Number of Apps Installed  Data Usage (MB/day)  Age  Gender
# 0                          67                 1122   40       1
# 1                          42                  944   47       0
# 2                          32                  322   42       1
# 3                          56                  871   20       1
# 4                          58                  988   31       0
# ..                        ...                  ...  ...     ...
# 695                        26                  381   22       1
# 696                        68                 1201   59       1
# 697                        22                  457   50       0
# 698                        13                  224   44       1
# 699                        49                  828   23       0
#
# [700 rows x 10 columns]

# %%
# select all rows except the last one
df.iloc[:,:-1]
# Out:
#      User ID  Device Model  Operating System  App Usage Time (min/day)  \
# 0          1             0                 0                       393
# 1          2             1                 0                       268
# 2          3             3                 0                       154
# 3          4             0                 0                       239
# 4          5             4                 1                       187
# ..       ...           ...               ...                       ...
# 695      696             4                 1                        92
# 696      697             3                 0                       316
# 697      698             0                 0                        99
# 698      699             2                 0                        62
# 699      700             1                 0                       212
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                           6.4                     1872
# 1                           4.7                     1331
# 2                           4.0                      761
# 3                           4.8                     1676
# 4                           4.3                     1367
# ..                          ...                      ...
# 695                         3.9                     1082
# 696                         6.8                     1965
# 697                         3.1                      942
# 698                         1.7                      431
# 699                         5.4                     1306
#
#      Number of Apps Installed  Data Usage (MB/day)  Age  Gender
# 0                          67                 1122   40       1
# 1                          42                  944   47       0
# 2                          32                  322   42       1
# 3                          56                  871   20       1
# 4                          58                  988   31       0
# ..                        ...                  ...  ...     ...
# 695                        26                  381   22       1
# 696                        68                 1201   59       1
# 697                        22                  457   50       0
# 698                        13                  224   44       1
# 699                        49                  828   23       0
#
# [700 rows x 10 columns]

# %%
target = 'User Behavior Class'
X = df.drop([target],axis=1)
Y= df[target]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2,shuffle=True)

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1, 3, 4, 2, 2, 2, 5, 1, 1, 1, 2, 3, 2, 4, 3, 1, 2, 4, 2, 1, 1, 4,
#        1, 5, 1, 3, 1, 3, 1, 2, 5, 5, 5, 3, 3, 4, 3, 4, 2, 4, 3, 5, 1, 5,
#        3, 1, 2, 5, 5, 4, 3, 1, 2, 4, 3, 3, 2, 3, 1, 1, 5, 2, 1, 3, 3, 5,
#        1, 1, 5, 3, 5, 2, 3, 3, 2, 3, 4, 1, 4, 4, 2, 5, 1, 2, 1, 4, 2, 3,
#        3, 1, 5, 2, 5, 4, 2, 1, 4, 2, 4, 4, 4, 4, 2, 3, 4, 2, 4, 3, 5, 1,
#        1, 2, 5, 5, 4, 4, 2, 4, 2, 1, 2, 4, 3, 2, 5, 4, 2, 3, 2, 5, 1, 2,
#        5, 5, 2, 1, 2, 1, 4, 2])

# %%
from sklearn.metrics import accuracy_score,f1_score,confusion_matrix

print(accuracy_score(y_test,y_pred))
print(f1_score(y_test,y_pred,average='micro'))
print(f1_score(y_test,y_pred,average='macro'))
print(confusion_matrix(y_test,y_pred))
# Out:
# 1.0
# 1.0
# 1.0
# [[30  0  0  0  0]
#  [ 0 34  0  0  0]
#  [ 0  0 26  0  0]
#  [ 0  0  0 27  0]
#  [ 0  0  0  0 23]]

# %% [markdown]
# # Exercise 5

# %%
import pandas as pd

df = pd.read_csv('Student_Performance.csv')
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
df['Extracurricular Activities'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

# Yes No --> {Yes:1,No:0} --> trans: changes into the list
df['Extracurricular Activities'] = encoder.fit_transform(df['Extracurricular Activities'])

# %%
encoder.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
target = 'Performance Index'
X=df.drop([target],axis=1)
Y = df[target]

# %%
X
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
#       Sample Question Papers Practiced
# 0                                    1
# 1                                    2
# 2                                    2
# 3                                    2
# 4                                    5
# ...                                ...
# 9995                                 2
# 9996                                 5
# 9997                                 5
# 9998                                 0
# 9999                                 1
#
# [10000 rows x 5 columns]

# %%
Y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %% [markdown]
# ### Linear Regression
#
# #### f(x) = b1x1 + b2x2 + b3x3 + b4x4 + b5x5 + b6

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %% [markdown]
# Make the dataset:
#
# Train --> the model will learn Test --> eval. of the model
#
# 80:20 70:30 90:10

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([2.85352109, 1.01959723, 0.59483017, 0.48314352, 0.1977199 ])

# %%
model.intercept_
# Out:
# np.float64(-34.177527651216565)

# %%
y_pred = model.predict(X_test)

# %%
Y.unique()
# Out:
# array([ 91.,  65.,  45.,  36.,  66.,  61.,  63.,  42.,  69.,  84.,  73.,
#         27.,  33.,  68.,  43.,  67.,  70.,  30.,  71.,  85.,  57.,  35.,
#         49.,  83.,  74.,  39.,  58.,  47.,  60.,  32.,  64.,  54.,  17.,
#         53.,  75.,  52.,  78.,  38.,  98.,  87.,  41.,  81.,  15.,  88.,
#         95.,  29.,  21.,  76.,  25.,  34.,  50.,  56.,  82.,  23.,  46.,
#         92.,  77.,  86.,  44.,  94.,  40., 100.,  31.,  26.,  18.,  51.,
#         72.,  16.,  28.,  89.,  48.,  37.,  62.,  59.,  19.,  79.,  22.,
#         10.,  90.,  80.,  24.,  20.,  96.,  55.,  97.,  12.,  93.,  14.,
#         99.,  11.,  13.])

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.9890954655668953

# %%
mean_absolute_error(Y_test,y_pred)
# Out:
# np.float64(1.5926720612039293)

# %%
Y_test.max(), Y_test.min()
# Out:
# (np.float64(100.0), np.float64(11.0))

# %%
mean_squared_error(Y_test,y_pred)
# Out:
# np.float64(4.07027859165259)

# %%
#Classification
len(df['Hours Studied'].unique())
# Out:
# 9

# %%
df['Hours Studied'].hist(bins=9)
# Out:
# <Axes: >

# %%
target = 'Hours Studied'
X= df.drop([target],axis=1)
Y= df[target]

# %%
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# C:\Users\imomc\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([4, 3, 7, ..., 1, 7, 7])

# %%
from sklearn.metrics import f1_score,classification_report

print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.44      0.75      0.55       225
#            2       0.28      0.09      0.14       211
#            3       0.26      0.26      0.26       222
#            4       0.26      0.28      0.27       206
#            5       0.34      0.23      0.27       241
#            6       0.29      0.36      0.32       213
#            7       0.36      0.42      0.39       230
#            8       0.44      0.38      0.41       240
#            9       0.70      0.67      0.69       212
#
#     accuracy                           0.38      2000
#    macro avg       0.38      0.38      0.37      2000
# weighted avg       0.38      0.38      0.37      2000

# %%
f1_score(Y_test,y_pred,average='macro')
# Out:
# np.float64(0.36638903845416193)

# %%
f1_score(Y_test,y_pred,average='micro')
# Out:
# np.float64(0.3825)

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier()

# %%
model.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(X_test)

# %%
f1_scores = []
for i in range(3,11):
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train,Y_train)
    y_pred = model.predict(X_test)
    f1_scores.append(f1_score(Y_test,y_pred,average='macro'))

# %%
import matplotlib.pyplot as plt
plt.plot([i for i in range(3,11)],f1_scores)
